# %% [markdown]
# # Initialiser client Boto 3

# %%
import os
import boto3
from pprint import pprint

s3 = boto3.client(
    "s3",
    endpoint_url=os.environ["S3_ENDPOINT_URL"],
    aws_access_key_id=os.environ["S3_ACCESS_KEY"],
    aws_secret_access_key=os.environ["S3_SECRET_KEY"],
    region_name="us-east-1",
)

# %% [markdown]
# # Lister des objets Boto3

# %%
bucket = os.environ["S3_BUCKET"]
resp = s3.list_objects_v2(Bucket=bucket, Prefix="welcometothejungle/bronze/")
[obj["Key"] for obj in resp.get("Contents", [])][:5]
# Out:
# ['welcometothejungle/bronze/dt=2026-02-16/run_id=20260216T071500Z/segment=jobs_html/key=ACADO_Pra7Opw/page.html.gz',
#  'welcometothejungle/bronze/dt=2026-02-16/run_id=20260216T071500Z/segment=jobs_html/key=BG_ZawZKxL/page.html.gz',
#  'welcometothejungle/bronze/dt=2026-02-16/run_id=20260216T071500Z/segment=jobs_html/key=CDLDMDA_pdZ1j7N/page.html.gz',
#  'welcometothejungle/bronze/dt=2026-02-16/run_id=20260216T071500Z/segment=jobs_html/key=CLIMB_5ypy6XD/page.html.gz',
#  'welcometothejungle/bronze/dt=2026-02-16/run_id=20260216T071500Z/segment=jobs_html/key=DECAT_VkmL92x/page.html.gz']

# %% [markdown]
# # Lire un JSONL (bronze) via boto3

# %%
key = "welcometothejungle/bronze/dt=2026-02-16/run_id=20260216T071715Z/segment=jobs_raw/part-000001.jsonl"

print(f"bucket={bucket}")
print(f"Key={key}")

obj = s3.get_object(Bucket=bucket, Key=key)
lines = obj["Body"].read().decode("utf-8").splitlines()
records = [json.loads(l) for l in lines if l.strip()]

print(" Nb elmts= " ,len(records))
print("Keys = ", records[0].keys())
print("")
#print(records[0].values())

for i, record in enumerate(records[:1]):
    #print(records[i]["initial_data"])
    if isinstance(records[i]["initial_data"], str):
        data = json.loads(records[i]["initial_data"])
    else:
        data = records[i]["initial_data"]  # déjà un dict !
    print(type(data))
    # Vue lisible
    #print(json.dumps(records[0], indent=2, ensure_ascii=False)[:2000] + "...")
    # Ou avec pprint (couleurs + compact)
    pprint(records[0]["job_data"], depth=3, width=80)
# Out:
# bucket=jobmarket
# Key=welcometothejungle/bronze/dt=2026-02-16/run_id=20260216T071715Z/segment=jobs_raw/part-000001.jsonl
#  Nb elmts=  500
# Keys =  dict_keys(['source', 'segment', 'url', 'fetched_at', 'status_code', 'ok', 'error', 'key', 'initial_data', 'job_data', 'parser_version'])
#
# <class 'dict'>
# {'application_fields': [{'id': 'd922d534-0c38-4955-bdca-c3de0062008e',
#                          'mode': 'mandatory',
#                          'name': 'cover_letter'},
#                         {'id': '553597c6-752a-48a1-be66-b6f57acc880b',
#                          'mode': 'mandatory',
#                          'name': 'resume'},
#                         {'id': '7d7fac81-9121-4eee-8d64-0a68b02f3289',
#                          'mode': 'disabled',
#                          'name': 'portfolio'},
#                         {'id': 'ef2555df-80b4-466a-b7dc-a1176a6221a4',
#                          'mode': 'optional',
#                          'name': 'picture'},
# ...
