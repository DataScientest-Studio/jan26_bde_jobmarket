# %%
import subprocess
subprocess.Popen(["streamlit", "run", "app.py"])
# Out:
# <Popen: returncode: None args: ['streamlit', 'run', 'app.py']>

# %%
# a utiliser dans le terminal avec le env actif
env_job_market\Scripts\Activate.ps1

Set-ExecutionPolicy -ExecutionPolicy RemoteSigned -Scope Process
env_job_market\Scripts\python.exe -m streamlit run streamlit/app.py
# Out:
#   Cell In[6], line 1
#     env_job_market\Scripts\python.exe -m streamlit run streamlit/app.py
#                    ^
# SyntaxError: unexpected character after line continuation character

# %%
pip install sqlalchemy
pip install sqlalchemy psycopg2-binary
pip install plotly
pip install folium

env_job_market\Scripts\python.exe -m pip install -r requirements.txt
env_job_market\Scripts\python.exe -m pip install folium streamlit-folium
env_job_market\Scripts\python.exe -m pip install sqlalchemy psycopg2-binary plotly
env_job_market\Scripts\python.exe -m pip install python-dotenv


env_job_market\Scripts\python.exe -m streamlit run streamlit/app.py
